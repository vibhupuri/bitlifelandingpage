# %%
# @title
from IPython.display import HTML
print("hello")
HTML('''<h2><span style='font-family: Comic Sans MS'> Hello World whatsapp:+852 60741430】【telegram:+852 60741430添加联系人】</span></h2>
<img alt="" src="data:image/png;base64,..." />''')
# Out:
# hello
# <h2><span style='font-family: Comic Sans MS'> Hello World whatsapp:+852 60741430】【telegram:+852 60741430添加联系人】</span></h2>
# <img alt="" src="data:image/png;base64,..." />
